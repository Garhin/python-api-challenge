# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from api_keys import weather_api_key
from citipy import citipy
 


# import os
# from requests.exceptions import ConnectionError
# from scipy.stats import linregress

# Output File (CSV)
# output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
print(cities)
# Out:
# ['bluff', 'souillac', 'assiniboia', 'port alfred', 'vaini', 'mahebourg', 'adrar', 'ilulissat', 'mataura', 'barrow', 'hobart', 'antsohihy', 'ushuaia', 'hasaki', 'dwarka', 'bagdarin', 'port elizabeth', 'halifax', 'mizpe ramon', 'itoman', 'busselton', 'albany', 'rikitea', 'carora', 'katsuura', 'bredasdorp', 'kurilsk', 'saint-philippe', 'kaitangata', 'puro', 'jamestown', 'thompson', 'nanchang', 'kintinku', 'taolanaro', 'kapaa', 'taoudenni', 'severo-kurilsk', 'fairbanks', 'belmonte', 'hilo', 'kurchum', 'butaritari', 'tabanan', 'carnarvon', 'sakaraha', 'houston', 'puerto ayora', 'nanakuli', 'mar del plata', 'vostok', 'tuktoyaktuk', 'san patricio', 'goundam', 'chokurdakh', 'porto velho', 'topolobampo', 'geresk', 'hlotse', 'georgetown', 'caravelas', 'arraial do cabo', 'lobito', 'amderma', 'barentsburg', 'caernarfon', 'loandjili', 'kupang', 'uyemskiy', 'punta arenas', 'saint-georges', 'kattivakkam', 'birjand', 'acapulco', 'la ronge', 'fortuna', 'cape town', 'dafeng', 'atuona', 'khatanga', 'maceio', 'faya', 'dikson', 'saskylakh', 'mehamn', 'broome', 'lata', 'new norfolk', 'samalaeulu', 'crab hill', 'leinefelde', 'cabo san lucas', 'moron', 'luderitz', 'naze', 'svay rieng', 'saint george', 'tura', 'hermanus', 'palatka', 'yerbogachen', 'davidson', 'seybaplaya', 'barberino di mugello', 'belushya guba', 'nangong', 'gannan', 'qaanaaq', 'alofi', 'westport', 'ostrovnoy', 'yabrud', 'labuhan', 'niksic', 'isangel', 'kaeo', 'grindavik', 'klaksvik', 'basco', 'bacuit', 'east london', 'nizhneyansk', 'bengkulu', 'najran', 'bourail', 'avarua', 'san cristobal', 'beatrice', 'victoria', 'anadyr', 'narsaq', 'westpunt', 'leningradskiy', 'mahajanga', 'dedougou', 'saleaula', 'kruisfontein', 'port blair', 'rundu', 'tasiilaq', 'codrington', 'yulara', 'lompoc', 'manta', 'lebu', 'ughelli', 'santa barbara', 'andevoranto', 'cortez', 'djambala', 'lingao', 'severodvinsk', 'petropavlovsk-kamchatskiy', 'bereznik', 'sinkat', 'vila franca do campo', 'wanning', 'lolua', 'saint anthony', 'sayyan', 'lorengau', 'sestri levante', 'cidreira', 'mundo nuevo', 'vung tau', 'arlit', 'bilibino', 'marcona', 'hofn', 'lodeynoye pole', 'imbituba', 'cam ranh', 'rio grande', 'nara', 'quatre cocos', 'eureka', 'arkhangelsk', 'sabzevar', 'robe', 'mangit', 'ribeira grande', 'ordu', 'impfondo', 'senmonorom', 'kavieng', 'sambava', 'los llanos de aridane', 'vaitupu', 'maple creek', 'kerki', 'kodiak', 'kosh-agach', 'chicama', 'tsihombe', 'banda aceh', 'sitka', 'ondorhaan', 'hithadhoo', 'prince rupert', 'wadersloh', 'geneva', 'abu dhabi', 'bonthe', 'moose factory', 'vao', 'aloleng', 'touros', 'ambodifototra', 'shimoda', 'kaseda', 'puerto leguizamo', 'skalistyy', 'maniitsoq', 'aklavik', 'mount gambier', 'ixtapa', 'kamenka', 'seabra', 'ligayan', 'mujiayingzi', 'troitskoye', 'yellowknife', 'gorontalo', 'kotka', 'nuuk', 'fare', 'piacabucu', 'honiara', 'srednekolymsk', 'karratha', 'hovd', 'babanusah', 'louga', 'zhanaozen', 'burkhala', 'shahumyan', 'bathsheba', 'ponta do sol', 'tarsus', 'walvis bay', 'longyearbyen', 'atar', 'belyy yar', 'marawi', 'sechura', 'nikolskoye', 'onufriyivka', 'sioux lookout', 'xichang', 'mitu', 'kununurra', 'kitimat', 'nishihara', 'bilma', 'iqaluit', 'gujar khan', 'guarapari', 'kainantu', 'kavaratti', 'sentyabrskiy', 'esperance', 'qandala', 'uray', 'naron', 'itarema', 'alice springs', 'ahipara', 'beira', 'sorong', 'koutiala', 'powell river', 'bambous virieux', 'clyde river', 'mayenne', 'kunri', 'avera', 'illoqqortoormiut', 'hamilton', 'faanui', 'morgan city', 'upernavik', 'cockburn town', 'luau', 'marang', 'husavik', 'berbera', 'berlevag', 'saint marys', 'cravo norte', 'cascais', 'bambanglipuro', 'cutervo', 'alta floresta', 'cabedelo', 'bulgan', 'viligili', 'sindal', 'sao filipe', 'saldanha', 'san quintin', 'coquimbo', 'natchitoches', 'tuatapere', 'praya', 'mys shmidta', 'san rafael', 'atambua', 'itaqui', 'pemberton', 'vardo', 'broken hill', 'madras', 'tiksi', 'harlingen', 'pevek', 'half moon bay', 'veraval', 'castro', 'astipalaia', 'hokitika', 'maneromango', 'talnakh', 'paamiu ...

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
city_name_list = []
cloudiness_list = []
country_list = []
date_list = []
humidity_list = []
lat_list = []
lng_list = []
max_temp_list = []
wind_speed_list = []
index_counter = 0
set_counter = 1

# %%
print("Beginning Data Retrieval ")
print("-----------------------------")

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={weather_api_key}&units={units}&q="
# query_url = f"{base_url}appid={api_keys}&units={units}&q="


# For each city name in cities list, do below things...
for index, city in enumerate(cities, start = 1):
    try:
        response = requests.get(query_url + city).json()
        city_name_list.append(response["name"])
        cloudiness_list.append(response["clouds"]["all"])
        country_list.append(response["sys"]["country"])
        date_list.append(response["dt"])
        humidity_list.append(response["main"]["humidity"])
        lat_list.append(response["coord"]["lat"])
        lng_list.append(response["coord"]["lon"])
        max_temp_list.append(response['main']['temp_max'])
        wind_speed_list.append(response["wind"]["speed"])
        if index_counter > 49:
            index_counter = 0
            set_counter = set_counter + 1
    
        else:
            index_counter = index_counter + 1
            
        print(f"Processing Record {index_counter} of Set {set_counter} : {city}") 
  
    except(KeyError, IndexError):
        print("City not found. Skipping...")

print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 : bluff
# Processing Record 2 of Set 1 : souillac
# Processing Record 3 of Set 1 : assiniboia
# Processing Record 4 of Set 1 : port alfred
# Processing Record 5 of Set 1 : vaini
# Processing Record 6 of Set 1 : mahebourg
# Processing Record 7 of Set 1 : adrar
# Processing Record 8 of Set 1 : ilulissat
# Processing Record 9 of Set 1 : mataura
# Processing Record 10 of Set 1 : barrow
# Processing Record 11 of Set 1 : hobart
# Processing Record 12 of Set 1 : antsohihy
# Processing Record 13 of Set 1 : ushuaia
# Processing Record 14 of Set 1 : hasaki
# Processing Record 15 of Set 1 : dwarka
# Processing Record 16 of Set 1 : bagdarin
# Processing Record 17 of Set 1 : port elizabeth
# Processing Record 18 of Set 1 : halifax
# City not found. Skipping...
# Processing Record 19 of Set 1 : itoman
# Processing Record 20 of Set 1 : busselton
# Processing Record 21 of Set 1 : albany
# Processing Record 22 of Set 1 : rikitea
# Processing Record 23 of Set 1 : carora
# Processing Record 24 of Set 1 : katsuura
# Processing Record 25 of Set 1 : bredasdorp
# Processing Record 26 of Set 1 : kurilsk
# Processing Record 27 of Set 1 : saint-philippe
# Processing Record 28 of Set 1 : kaitangata
# Processing Record 29 of Set 1 : puro
# Processing Record 30 of Set 1 : jamestown
# Processing Record 31 of Set 1 : thompson
# Processing Record 32 of Set 1 : nanchang
# Processing Record 33 of Set 1 : kintinku
# City not found. Skipping...
# Processing Record 34 of Set 1 : kapaa
# Processing Record 35 of Set 1 : taoudenni
# Processing Record 36 of Set 1 : severo-kurilsk
# Processing Record 37 of Set 1 : fairbanks
# Processing Record 38 of Set 1 : belmonte
# Processing Record 39 of Set 1 : hilo
# Processing Record 40 of Set 1 : kurchum
# Processing Record 41 of Set 1 : butaritari
# Processing Record 42 of Set 1 : tabanan
# Processing Record 43 of Set 1 : carnarvon
# Processing Record 44 of Set 1 : sakaraha
# Processing Record 45 of Set 1 : houston
# Processing Record 46 of Set 1 : puerto ayora
# Processing Record 47 of Set 1 : nanakuli
# Processing Record 48 of Set 1 : mar del plata
# Processing Record 49 of Set 1 : vostok
# Processing Record 50 of Set 1 : tuktoyaktuk
# Processing Record 0 of Set 2 : san patricio
# Processing Record 1 of Set 2 : goundam
# Processing Record 2 of Set 2 : chokurdakh
# Processing Record 3 of Set 2 : porto velho
# Processing Record 4 of Set 2 : topolobampo
# City not found. Skipping...
# Processing Record 5 of Set 2 : hlotse
# Processing Record 6 of Set 2 : georgetown
# Processing Record 7 of Set 2 : caravelas
# Processing Record 8 of Set 2 : arraial do cabo
# Processing Record 9 of Set 2 : lobito
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 10 of Set 2 : caernarfon
# Processing Record 11 of Set 2 : loandjili
# Processing Record 12 of Set 2 : kupang
# Processing Record 13 of Set 2 : uyemskiy
# Processing Record 14 of Set 2 : punta arenas
# Processing Record 15 of Set 2 : saint-georges
# Processing Record 16 of Set 2 : kattivakkam
# Processing Record 17 of Set 2 : birjand
# Processing Record 18 of Set 2 : acapulco
# Processing Record 19 of Set 2 : la ronge
# Processing Record 20 of Set 2 : fortuna
# Processing Record 21 of Set 2 : cape town
# Processing Record 22 of Set 2 : dafeng
# Processing Record 23 of Set 2 : atuona
# Processing Record 24 of Set 2 : khatanga
# Processing Record 25 of Set 2 : maceio
# Processing Record 26 of Set 2 : faya
# Processing Record 27 of Set 2 : dikson
# Processing Record 28 of Set 2 : saskylakh
# Processing Record 29 of Set 2 : mehamn
# Processing Record 30 of Set 2 : broome
# Processing Record 31 of Set 2 : lata
# Processing Record 32 of Set 2 : new norfolk
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 33 of Set 2 : leinefelde
# Processing Record 34 of Set 2 : cabo san lucas
# Processing Record 35 of Set 2 : moron
# Processing Record 36 of Set 2 : luderitz
# Processing Record 37 of Set 2 : naze
# Processing Record 38 of Set 2 : svay rieng
# Processing Record 39 of Set 2 : saint george
# Processing Record 40 of Set 2 : tura
# Processing Record 41 of Set 2 : hermanus
# Processing Record 42 of Set 2 : palatka
# Processing Record 43 of Set 2 : yerbogachen
# Processing Record 44 of Set 2 : davidson
# Processing Record 45 of Set 2 : seybaplaya
# Processing Record 46 of Set 2 : barberino di mugello
# City not found. Skipping...
# Processing Record 47 of Set 2 : nangong
# Processing Record 48 of Set 2 : gannan
# Processing Record 49 of Set 2 : qaanaaq
# Processing Record 50 of Set 2 : alofi
# Processing Record 0 of Set 3 : westport
# Processing Record 1 of Set 3 : ostrovnoy
# Processing Record 2 of Set 3 : yabrud
# Processing Record 3 of Set 3 : labuhan
# Processing Record 4 of Set 3 : niksic
# Processing Record 5 of Set 3 : isangel
# Processing Record 6 of Set 3 : kaeo
# Processing Record 7 of Set 3 : grindavik
# Processing Record 8 of Set 3 : klaksvik
# Processing Record 9 of Set 3 : basco
# City not found. Skipping...
# Processing Record 10 of Set 3 : east london
# City not found. Skipping...
# Processing Record 11 of Set 3 : bengkulu
# Processing Record 12 of Set 3 : najran
# Processing Record 13 of Set 3 : bourail
# Processing Record 14 of Set 3 : avarua
# Processing Record 15 of Set 3 : san cristobal
# Processing Record 16 of Set 3 : beatrice
# Processing Record 17 of Set 3 : victoria
# Processing Record 18 of Set 3 : anadyr
# Processing Record 19 of Set 3 : narsaq
# City not found. Skipping...
# Processing Record 20 of Set 3 : leningradskiy
# Processing Record 21 of Set 3 : mahajanga
# Processing Record 22 of Set 3 : dedougou
# City not found. Skipping...
# Processing Record 23 of Set 3 : kruisfontein
# Processing Record 24 of Set 3 : port blair
# Processing Record 25 of Set 3 : rundu
# Processing Record 26 of Set 3 : tasiilaq
# Processing Record 27 of Set 3 : codrington
# Processing Record 28 of Set 3 : yulara
# Processing Record 29 of Set 3 : lompoc
# Processing Record 30 of Set 3 : manta
# Processing Record 31 of Set 3 : lebu
# Processing Record 32 of Set 3 : ughelli
# Processing Record 33 of Set 3 : santa barbara
# City not found. Skipping...
# Processing Record 34 of Set 3 : cortez
# Processing Record 35 of Set 3 : djambala
# Processing Record 36 of Set 3 : lingao
# Processing Record 37 of Set 3 : severodvinsk
# Processing Record 38 of Set 3 : petropavlovsk-kamchatskiy
# Processing Record 39 of Set 3 : bereznik
# City not found. Skipping...
# Processing Record 40 of Set 3 : vila franca do campo
# Processing Record 41 of Set 3 : wanning
# City not found. Skipping...
# Processing Record 42 of Set 3 : saint anthony
# Processing Record 43 of Set 3 : sayyan
# Processing Record 44 of Set 3 : lorengau
# Processing Record 45 of Set 3 : sestri levante
# Processing Record 46 of Set 3 : cidreira
# Processing Record 47 of Set 3 : mundo nuevo
# Processing Record 48 of Set 3 : vung tau
# Processing Record 49 of Set 3 : arlit
# Processing Record 50 of Set 3 : bilibino
# City not found. Skipping...
# Processing Record 0 of Set 4 : hofn
# Processing Record 1 of Set 4 : lodeynoye pole
# Processing Record 2 of Set 4 : imbituba
# Processing Record 3 of Set 4 : cam ranh
# Processing Record 4 of Set 4 : rio grande
# Processing Record 5 of Set 4 : nara
# Processing Record 6 of Set 4 : quatre cocos
# Processing Record 7 of Set 4 : eureka
# Processing Record 8 of Set 4 : arkhangelsk
# Processing Record 9 of Set 4 : sabzevar
# Processing Record 10 of Set 4 : robe
# Processing Record 11 of Set 4 : mangit
# Processing Record 12 of Set 4 : ribeira grande
# Processing Record 13 of Set 4 : ordu
# Processing Record 14 of Set 4 : impfondo
# City not found. Skipping...
# Processing Record 15 of Set 4 : kavieng
# Processing Record 16 of Set 4 : sambava
# Processing Record 17 of Set 4 : los llanos de aridane
# City not found. Skipping...
# Processing Record 18 of Set 4 : maple creek
# City not found. Skipping...
# Processing Record 19 of Set 4 : kodiak
# Processing Record 20 of Set 4 : kosh-agach
# Processing Record 21 of Set 4 : chicama
# City not found. Skipping...
# Processing Record 22 of Set 4 : banda aceh
# Processing Record 23 of Set 4 : sitka
# City not found. Skipping...
# Processing Record 24 of Set 4 : hithadhoo
# Processing Record 25 of Set 4 : prince rupert
# Processing Record 26 of Set 4 : wadersloh
# Processing Record 27 of Set 4 : geneva
# Processing Record 28 of Set 4 : abu dhabi
# Processing Record 29 of Set 4 : bonthe
# Processing Record 30 of Set 4 : moose factory
# Processing Record 31 of Set 4 : vao
# Processing Record 32 of Set 4 : aloleng
# Processing Record 33 of Set 4 : touros
# City not found. Skipping...
# Processing Record 34 of Set 4 : shimoda
# Processing Record 35 of Set 4 : kaseda
# Processing Record 36 of Set 4 : puerto leguizamo
# City not found. Skipping...
# Processing Record 37 of Set 4 : maniitsoq
# Processing Record 38 of Set 4 : aklavik
# Processing Record 39 of Set 4 : mount gambier
# Processing Record 40 of Set 4 : ixtapa
# Processing Record 41 of Set 4 : kamenka
# Processing Record 42 of Set 4 : seabra
# Processing Record 43 of Set 4 : ligayan
# Processing Record 44 of Set 4 : mujiayingzi
# Processing Record 45 of Set 4 : troitskoye
# Processing Record 46 of Set 4 : yellowknife
# Processing Record 47 of Set 4 : gorontalo
# Processing Record 48 of Set 4 : kotka
# Processing Record 49 of Set 4 : nuuk
# Processing Record 50 of Set 4 : fare
# Processing Record 0 of Set 5 : piacabucu
# Processing Record 1 of Set 5 : honiara
# Processing Record 2 of Set 5 : srednekolymsk
# Processing Record 3 of Set 5 : karratha
# Processing Record 4 of Set 5 : hovd
# City not found. Skipping...
# Processing Record 5 of Set 5 : louga
# Processing Record 6 of Set 5 : zhanaozen
# City not found. Skipping...
# Processing Record 7 of Set 5 : shahumyan
# Processing Record 8 of Set 5 : bathsheba
# Processing Record 9 of Set 5 : ponta do sol
# Processing Record 10 of Set 5 : tarsus
# Processing Record 11 of Set 5 : walvis bay
# Processing Record 12 of Set 5 : longyearbyen
# Processing Record 13 of Set 5 : atar
# Processing Record 14 of Set 5 : belyy yar
# Processing Record 15 of Set 5 : marawi
# Processing Record 16 of Set 5 : sechura
# Processing Record 17 of Set 5 : nikolskoye
# Processing Record 18 of Set 5 : onufriyivka
# Processing Record 19 of Set 5 : sioux lookout
# Processing Record 20 of Set 5 : xichang
# Processing Record 21 of Set 5 : mitu
# Processing Record 22 of Set 5 : kununurra
# Processing Record 23 of Set 5 : kitimat
# Processing Record 24 of Set 5 : nishihara
# Processing Record 25 of Set 5 : bilma
# Processing Record 26 of Set 5 : iqaluit
# Processing Record 27 of Set 5 : gujar khan
# Processing Record 28 of Set 5 : guarapari
# Processing Record 29 of Set 5 : kainantu
# Processing Record 30 of Set 5 : kavaratti
# City not found. Skipping...
# Processing Record 31 of Set 5 : esperance
# Processing Record 32 of Set 5 : qandala
# Processing Record 33 of Set 5 : uray
# Processing Record 34 of Set 5 : naron
# Processing Record 35 of Set 5 : itarema
# Processing Record 36 of Set 5 : alice springs
# Processing Record 37 of Set 5 : ahipara
# Processing Record 38 of Set 5 : beira
# Processing Record 39 of Set 5 : sorong
# Processing Record 40 of Set 5 : koutiala
# Processing Record 41 of Set 5 : powell river
# Processing Record 42 of Set 5 : bambous virieux
# Processing Record 43 of Set 5 : clyde river
# Processing Record 44 of Set 5 : mayenne
# Processing Record 45 of Set 5 : kunri
# Processing Record 46 of Set 5 : avera
# City not found. Skipping...
# Processing Record 47 of Set 5 : hamilton
# Processing Record 48 of Set 5 : faanui
# Processing Record 49 of Set 5 : morgan city
# Processing Record 50 of Set 5 : upernavik
# Processing Record 0 of Set 6 : cockburn town
# Processing Record 1 of Set 6 : luau
# Processing Record 2 of Set 6 : marang
# Processing Record 3 of Set 6 : husavik
# Processing Record 4 of Set 6 : berbera
# Processing Record 5 of Set 6 : berlevag
# Processing Record 6 of Set 6 : saint marys
# Processing Record 7 of Set 6 : cravo norte
# Processing Record 8 of Set 6 : cascais
# Processing Record 9 of Set 6 : bambanglipuro
# Processing Record 10 of Set 6 : cutervo
# Processing Record 11 of Set 6 : alta floresta
# Processing Record 12 of Set 6 : cabedelo
# Processing Record 13 of Set 6 : bulgan
# City not found. Skipping...
# Processing Record 14 of Set 6 : sindal
# Processing Record 15 of Set 6 : sao filipe
# Processing Record 16 of Set 6 : saldanha
# Processing Record 17 of Set 6 : san quintin
# Processing Record 18 of Set 6 : coquimbo
# Processing Record 19 of Set 6 : natchitoches
# Processing Record 20 of Set 6 : tuatapere
# Processing Record 21 of Set 6 : praya
# City not found. Skipping...
# Processing Record 22 of Set 6 : san rafael
# Processing Record 23 of Set 6 : atambua
# Processing Record 24 of Set 6 : itaqui
# Processing Record 25 of Set 6 : pemberton
# Processing Record 26 of Set 6 : vardo
# Processing Record 27 of Set 6 : broken hill
# Processing Record 28 of Set 6 : madras
# Processing Record 29 of Set 6 : tiksi
# Processing Record 30 of Set 6 : harlingen
# Processing Record 31 of Set 6 : pevek
# Processing Record 32 of Set 6 : half moon bay
# Processing Record 33 of Set 6 : veraval
# Processing Record 34 of Set 6 : castro
# City not found. Skipping...
# Processing Record 35 of Set 6 : hokitika
# Processing Record 36 of Set 6 : maneromango
# Processing Record 37 of Set 6 : talnakh
# Processing Record 38 of Set 6 : paamiut
# Processing Record 39 of Set 6 : takoradi
# Processing Record 40 of Set 6 : huarmey
# City not found. Skipping...
# Processing Record 41 of Set 6 : bay roberts
# Processing Record 42 of Set 6 : tilichiki
# Processing Record 43 of Set 6 : ponerihouen
# Processing Record 44 of Set 6 : providencia
# Processing Record 45 of Set 6 : norman wells
# Processing Record 46 of Set 6 : shakawe
# Processing Record 47 of Set 6 : storforshei
# City not found. Skipping...
# Processing Record 48 of Set 6 : jardim
# City not found. Skipping...
# Processing Record 49 of Set 6 : bucerias
# Processing Record 50 of Set 6 : campoverde
# Processing Record 0 of Set 7 : vila do maio
# Processing Record 1 of Set 7 : masvingo
# Processing Record 2 of Set 7 : pacific grove
# Processing Record 3 of Set 7 : umm kaddadah
# Processing Record 4 of Set 7 : kenai
# Processing Record 5 of Set 7 : svetlogorsk
# Processing Record 6 of Set 7 : hastings
# Processing Record 7 of Set 7 : tazovskiy
# Processing Record 8 of Set 7 : cayenne
# Processing Record 9 of Set 7 : togur
# Processing Record 10 of Set 7 : da lat
# Processing Record 11 of Set 7 : noumea
# Processing Record 12 of Set 7 : te anau
# Processing Record 13 of Set 7 : geraldton
# Processing Record 14 of Set 7 : le vauclin
# Processing Record 15 of Set 7 : callaway
# Processing Record 16 of Set 7 : champerico
# Processing Record 17 of Set 7 : richards bay
# Processing Record 18 of Set 7 : juneau
# Processing Record 19 of Set 7 : san jose
# Processing Record 20 of Set 7 : cosio
# Processing Record 21 of Set 7 : san miguelito

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = pd.DataFrame({ 
                "City" : city_name_list,
                "Cloudiness" : cloudiness_list,
                "Country" : country_list,
                "Date" : date_list,
                "Humidity" : humidity_list,
                "Lat" : lat_list,
                "Lng" : lng_list,
                "Max Temp" : max_temp_list,
                "Wind Speed" : wind_speed_list
})

# %%
# Count data
weather_dict.count()

# %%
# Display the Data Frame
weather_dict

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Create Latitude vs. Temperature Plot scatter plot
plt.scatter(weather_dict["Lat"], weather_dict["Max Temp"], facecolor = "steelblue", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Max Temperature (01/17/20)")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Max Temperature (F)")

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("../Images/heatmap.png")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Create Latitude vs. Humidity Plot scatter plot
plt.scatter(weather_dict["Lat"], weather_dict["Humidity"], facecolor = "steelblue", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Humidity (01/17/20)")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Humidity (%)")

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("../Images/City Latitude vs Humidity.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Create Latitude vs. Cloudiness Plot scatter plot
plt.scatter(weather_dict["Lat"], weather_dict["Cloudiness"], facecolor = "steelblue", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Cloudiness (01/17/20)")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Cloudiness (%)")

# Set y axis limit
plt.ylim(-5,105)

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("../Images/City Latitude vs Cloudiness.png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Create Latitude vs. Wind Speed scatter plot
plt.scatter(weather_dict["Lat"], weather_dict["Wind Speed"], facecolor = "steelblue", edgecolor = "black")
plt.title("City Latitude vs. Wind Speed (mph) (01/17/20)")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Wind Speed (%)")

# Set y axis limit
plt.ylim(-2,50)

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("../Images/City Latitude vs Wind Speed (mph).png")

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemisphere = weather_dict.loc[weather_dict["Lat"] >= 0]
southern_hemisphere = weather_dict.loc[weather_dict["Lat"] < 0]

# %%
# Define function for creating linear agression and scatter plot
def linear_agression(x,y):
    print(f"The r-squared is : {round(st.pearsonr(x, y)[0],2)}")
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y)
    plt.plot(x,regress_values,"r-")
    return line_eq

# Define a fuction for annotating
def annotate(line_eq, a, b):
    plt.annotate(line_eq,(a,b),fontsize=15,color="red")

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Max Temp"])

# Call an function #2
annotate(equation, 0, 0)

# Set a title
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Max Temp (F)")

# Save the figure
plt.savefig("../Images/Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png")

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(southern_hemisphere["Lat"],southern_hemisphere["Max Temp"])

# Call an function #2
annotate(equation, -30, 50)

# Set a title
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Max Temp (F)")

# Save the figure
plt.savefig("../Images/Southern Hemisphere - Max Temp vs. Latitude Linear Regression.png")

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Humidity"])

# Call an function #2
annotate(equation, 40, 15)

# Set a title
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("../Images/Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Humidity"])

# Call an function #2
annotate(equation, -40, 50)

# Set title
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("../Images/Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Cloudiness"])

# Call an function #2
annotate(equation, 30, 40)

# Set a title
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("../Images/Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Cloudiness"])

# Call an function #2
annotate(equation, -30, 40)

# Set a title
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("../Images/Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Wind Speed"])

# Call an function #2
annotate(equation, 40, 20)

# Set  title
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Wind Speed (mph)")

# Save the figure
plt.savefig("../Images/Northern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
